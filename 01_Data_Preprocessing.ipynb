# %%
import pandas as pd

# %%
df = pd.read_csv("Airline_Delay_Cause.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101315 entries, 0 to 101314
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Year                     101315 non-null  int64
#  1   Month                    101315 non-null  int64
#  2   AirlineCode              101315 non-null  object
#  3   AirportCode              101315 non-null  object
#  4   TotalFlights             101157 non-null  float64
#  5   FlightsDelayedOver15Min  100960 non-null  float64
#  6   CarrierDelayCount        101157 non-null  float64
#  7   WeatherDelayCount        101157 non-null  float64
#  8   NASDelayCount            101157 non-null  float64
#  9   SecurityDelayCount       101157 non-null  float64
#  10  LateAircraftDelayCount   101157 non-null  float64
#  11  CancelledFlights         101157 non-null  float64
#  12  DivertedFlights          101157 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Year                         0
# Month                        0
# AirlineCode                  0
# AirportCode                  0
# TotalFlights               158
# FlightsDelayedOver15Min    355
# CarrierDelayCount          158
# WeatherDelayCount          158
# NASDelayCount              158
# SecurityDelayCount         158
# LateAircraftDelayCount     158
# CancelledFlights           158
# DivertedFlights            158
# ArrivalDelayMinutes        158
# dtype: int64

# %%
df = df.dropna()
df = df.copy()
df.shape
# Out:
# (100960, 14)

# %%
df["AirlineCode"].unique()[:10]
# Out:
# array(['9E', 'AA', 'AS', 'B6', 'DL', 'F9', 'G4', 'HA', 'MQ', 'NK'],
#       dtype=object)

# %%
df["AirportCode"].unique()[:10]
# Out:
# array(['ABE', 'ABY', 'ACK', 'AEX', 'AGS', 'ALB', 'ATL', 'ATW', 'AUS',
#        'AVL'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_airline = LabelEncoder()

# %%
df["AirlineCode"] = le_airline.fit_transform(df["AirlineCode"])

# %%
df["AirlineCode"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: AirlineCode, dtype: int64

# %%
df["AirlineCode"].unique()[:10]
# Out:
# array([ 0,  1,  2,  3,  4,  6,  7,  8,  9, 10])

# %%
le_airport = LabelEncoder()

# %%
df["AirportCode"] = le_airport.fit_transform(df["AirportCode"])

# %%
df["AirportCode"].head()
# Out:
# 0     0
# 1     4
# 2     5
# 3    11
# 4    12
# Name: AirportCode, dtype: int64

# %%
df.head()
# Out:
#    Year  Month  AirlineCode  AirportCode  TotalFlights  \
# 0  2022      7            0            0          33.0
# 1  2022      7            0            4          78.0
# 2  2022      7            0            5         124.0
# 3  2022      7            0           11          67.0
# 4  2022      7            0           12         174.0
#
#    FlightsDelayedOver15Min  CarrierDelayCount  WeatherDelayCount  \
# 0                      2.0               0.92               1.00
# 1                     25.0              11.80               0.72
# 2                     19.0               5.84               1.00
# 3                     10.0               1.32               1.00
# 4                     30.0              18.10               5.75
#
#    NASDelayCount  SecurityDelayCount  LateAircraftDelayCount  \
# 0           0.08                 0.0                    0.00
# 1           5.01                 0.0                    7.48
# ...

# %%
df["Delayed"] = (df["ArrivalDelayMinutes"] > 15).astype(int)

# %%
df[["ArrivalDelayMinutes","Delayed"]].head()
# Out:
#    ArrivalDelayMinutes  Delayed
# 0                129.0        1
# 1               1664.0        1
# 2               1523.0        1
# 3                657.0        1
# 4               2462.0        1

# %%
X = df.drop (["ArrivalDelayMinutes", "Delayed"], axis = 1)

# %%
X.head()
# Out:
#    Year  Month  AirlineCode  AirportCode  TotalFlights  \
# 0  2022      7            0            0          33.0
# 1  2022      7            0            4          78.0
# 2  2022      7            0            5         124.0
# 3  2022      7            0           11          67.0
# 4  2022      7            0           12         174.0
#
#    FlightsDelayedOver15Min  CarrierDelayCount  WeatherDelayCount  \
# 0                      2.0               0.92               1.00
# 1                     25.0              11.80               0.72
# 2                     19.0               5.84               1.00
# 3                     10.0               1.32               1.00
# 4                     30.0              18.10               5.75
#
#    NASDelayCount  SecurityDelayCount  LateAircraftDelayCount  \
# 0           0.08                 0.0                    0.00
# 1           5.01                 0.0                    7.48
# ...

# %%
y = df["Delayed"]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Delayed, dtype: int64

# %%
df.to_csv("cleaned_flight_delay.csv", index=False)
